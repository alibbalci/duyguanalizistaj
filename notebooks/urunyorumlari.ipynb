# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    "hepsiburada_balanced_300k.csv",
    
)

df.head(250)
# Out:
#                                          combined_text  label
# 0                                      İki Yıldız. iyi      0
# 1    Bir Yıldız. kargo sorunsuz geldi ama tam 1 haf...      0
# 2    Kokusu dışında iş görür. Çok fazla koku yapıyo...      0
# 3    kötü. saat içinden çıkıyor beklediğim gibi kal...      0
# 4    Çok kötü.... Almayın çok kötü boşa para verirs...      0
# ..                                                 ...    ...
# 245               Bir Yıldız. Tül gibi bildiğin süzgeç      0
# 246     bi fark görmedim. bi fark göremedim boşa aldım      0
# 247  İki Yıldız. Lapa icindeki parmak girislerinde ...      0
# 248  berbat. saclarimi aslan yelesi gibi yapti sacl...      0
# 249  Bandana . Bu zamana kadar hepsiburadadan aldığ...      0
#
# [250 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   combined_text  300000 non-null  object
#  1   label          300000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 4.6+ MB

# %%
print(df.shape)
# Out:
# (300000, 2)

# %%
print(df["label"].value_counts())
# Out:
# label
# 0    100000
# 1    100000
# 2    100000
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# combined_text    0
# label            0
# dtype: int64

# %%
print(df["combined_text"].duplicated().sum())
# Out:
# 53018

# %%
celiskili_metinler = (
    df.groupby("combined_text")["label"]
      .nunique()
)

celiskili_metinler = celiskili_metinler[celiskili_metinler > 1]

print("Farklı etiketli aynı metin sayısı:", len(celiskili_metinler))
# Out:
# Farklı etiketli aynı metin sayısı: 33

# %%
df[df["combined_text"].isin(celiskili_metinler.index)] \
    .sort_values("combined_text") \
    .head(30)
# Out:
#                                             combined_text  label
# 194260  Anakart Yanıyor. Kesinlikle almayın Bir süre s...      1
# 82663   Anakart Yanıyor. Kesinlikle almayın Bir süre s...      0
# 243341                                 Başarılı. Başarılı      2
# 190099                                 Başarılı. Başarılı      1
# 186680                                 Başarılı. Başarılı      1
# 107076                                 Başarılı. Başarılı      1
# 220910                                 Başarılı. Başarılı      2
# 126923                                 Başarılı. Başarılı      1
# 289170  F/P. indirimde bulursanız kaçırmayın ben indir...      2
# 124336  F/P. indirimde bulursanız kaçırmayın ben indir...      1
# 293209  Gayet iyi. Fiyatına göre çok iyi bir ürün tavs...      2
# 107156  Gayet iyi. Fiyatına göre çok iyi bir ürün tavs...      1
# 178105  Gayet iyi. Fiyatına göre çok iyi bir ürün tavs...      1
# 110856                                       Guzel. Guzel      1
# 298458                                       Guzel. Guzel      2
# 197449                                       Guzel. Guzel      1
# 239493                                       Guzel. Guzel      2
# 259238                                       Guzel. Guzel      2
# 231541  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 229387  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 289831  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 286950  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 227909  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 200146  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 227281  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 226466  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 293616  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 223857  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 223040  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2
# 221142  Güzel bir ürün. Bu gerçekten iyi bir üründür y...      2

# %%
# Aynı metnin kaç farklı etiketi olduğunu bul
etiket_sayilari = (
    df.groupby("combined_text")["label"]
      .nunique()
)

# Birden fazla etikete sahip metinler
celiskili_metinler = etiket_sayilari[
    etiket_sayilari > 1
].index

print("Çelişkili metin sayısı:", len(celiskili_metinler))

# Çelişkili metinlerin bütün satırlarını çıkar
df_temiz = df[
    ~df["combined_text"].isin(celiskili_metinler)
].copy()

# Geri kalan aynı metinlerden yalnızca ilkini bırak
df_temiz = df_temiz.drop_duplicates(
    subset=["combined_text"],
    keep="first"
)

# İndeksi sıfırla
df_temiz = df_temiz.reset_index(drop=True)
# Out:
# Çelişkili metin sayısı: 33

# %%
print("Eski boyut:", df.shape)
print("Yeni boyut:", df_temiz.shape)

print("\nSınıf dağılımı:")
print(df_temiz["label"].value_counts().sort_index())

print("\nKalan duplicate:")
print(df_temiz["combined_text"].duplicated().sum())

print("\nKalan çelişkili metin:")
print(
    (df_temiz.groupby("combined_text")["label"].nunique() > 1).sum()
)
# Out:
# Eski boyut: (300000, 2)
# Yeni boyut: (246949, 2)
#
# Sınıf dağılımı:
# label
# 0    77186
# 1    79219
# 2    90544
# Name: count, dtype: int64
#
# Kalan duplicate:
# 0
#
# Kalan çelişkili metin:
# 0

# %%
# Her sınıftan rastgele 10 örnek incele
for etiket in sorted(df_temiz["label"].unique()):
    print("\n" + "=" * 50)
    print("LABEL:", etiket)
    print("=" * 50)

    ornekler = df_temiz[df_temiz["label"] == etiket].sample(
        10,
        random_state=42
    )

    for metin in ornekler["combined_text"]:
        print("-", metin)
# Out:
# ==================================================
# LABEL: 0
# ==================================================
# - paketleniş süper. ışığı tahmin ettiğimden daha güçlü çıkmasına karşın daha ilk kullanışta aç kapa tuşu kırıldı
# - resimde gözüktüğü gibi kalın değil . Ürün resimdeki gibi şeffaf kısmı kalın değil işimi görmeyecek nikelaj yapıştırmak için almıştım başka işlerde kullanılabilir hızlı kargo için teşekkürler
# - İki Yıldız. Beklenen tost keyfini yaşamak için çok zayıf bir makina Rezistansı çok çabuk devreden çıkıyor ve tost yapmak için uzun süre beklemeniz gerekiyor Fiyatının çok altında bir kalitede
# - Daha iyisi var. Kulaklığın bass sesleri zayıf ve dış sesleri fazla geçiriyor pek memnun kalmadım Bu fiyatlara kardeşime Anker marka kablosuz kulaklık almıştım ses kalitesi çok daha tatmin ediciydi ve su geçirmezdi bunun yerine onu tavsiye ederim
# - cok kotu. hemen yan odadan bile cekmiyor kamera ile el unitesi arasinda 10 mt yok ama surekli sebeke sinyali veriyor ve gece gorusu hicbir ise yaramaz
# - memnuniyetsiz.. 07 06 2018 perşembe gün Abre Vm 348345 Ceviz Vestiyer Portmanto Ayakkabılık sipariş verdim 13 06 2018 tarihinde yaklasık bir hafta sonra kargoya yeni verilmiş bugün 16 06 2018 halen kargo samsuna ulasmadı bu kargo samsun aktarmalıda giresuna gelecek bu nasıl bir çalışma anlamıs değilim yıllardır internet üzerinden alışveriş yaparım hiçbir siparişimin elime ulaşması 1 haftayı geçmedi masallah bunlara kablumbağa hızında ilerliyor sanırım bu ay içinde elime ulaşır
# - Berbat. Sanki odunBu kadar kalitesiz olacaği aklıma gelmezdi Yorumlar yanılttı Saptaki kıymıklar elinize batar Pedler bilya büyüklüğunde ezik Yan bantlar bildiğiniz ince kırmızı kurdela Ağır mi agır Şiddetle almamanızı oneririm
# - hemen cikiyor. chico biberona taktik ama bebegim hemen cikariyor elleriyle tavsiye etmiyorum
# - İki Yıldız. Teslimat çok gecikmeli
# - Berbat. Çok Kalitesiz
#
# ==================================================
# LABEL: 1
# ==================================================
# - Renk farklı ayakların genişlikleri farklı. Ürün iyi paketlenmiş olmasına rağmen ayaklarda ki vidalama kulakları yamulmuş Kargo şirketinin işi Ayaklar biraz kalitesiz 78 cm 200 cm 4 cm geldimasa Doğal ahşap sağlam güzel duruyor Rengi turuncuya yakın geldi Resimde ki gibi naturel kahve bekliyordum Neyse emeğe saygı antalyadan istanbula kargolandı İade etmeyeceğim Ama bekleneni karşılamadı
# - orjinal bir ürün. ürünü sipariş verdikten sonra tedarik sürecinin ardından elime çok hızlı ulaştı montajı gayet kolay her birleşme yerinde 2 vida bulunuyor ürün gayet sağlam dijital göstergesi fazla fazla gösteriyor çektiğim mekikleri mekik çekerken sırtınızı ağrıtmıyor bence bu en iyi özelliği bu
# - Üç Yıldız. kullanmadım ama kaliteliye benziyor paketlemesi falan güzeldi tavsiye ederim hepsi buradaya teşekürler
# - NE İYİ NE KÖTÜ. ÜRÜN BELİRTİLDİĞİ GİBİ TEK KUTU DA 2 Lİ GELDİ MALZEME OLARAK ÇOK TA KALİTELİ DEĞİL DAHA KALİTELİ OLABİLİRDİ DÜZGÜN YAPIŞTIRLMASI GEREKİYOR
# - İdare eder. Topu köpükten basit bir şey
# - gayet iyi bir ürün. üründen daha fazla basınçla üfleme potansiyeli beklediğim için biraz az geldi fakat sıcaklık olarak çok iyi potansiyele sahip
# - tavsiye ederim. Benim köpeğim yok kedilerim var Arkadaşlarımın köpeklerini seviyorum onlara alıyorum Çok severek yiyorlar
# - hala alamadim urunlerii. benzer urunlerden kampanyali hediyeli3 adet siparis verdim demeyide yaptim fakat hala urunler gelmedi bi aciklamada yok kargoya verildigine dair bir mailfe yok bi aciklama bekliyorum madurumm
# - Sessiz sayılabilir. Dünyanın en sessiz ürünü değil tabii 1 2 3 seviyeler yavaş olduğu için gürültüsü daha az ama benzer kaliteli ürünler de aynı gürültü seviyesine sahiptirler Rüzgar sesi az olmakla beraber motor uğultusu olmaması gereken bir ses 1 3 seviyelerde sürekli değişmeyen bir uğultu var 4 5 seviyeler ise epey gürültülü diğerler ürünler ile aynı sanırım 50wattlık ampülleri az aydınlatıyor ve 50watt da epey bir abartılı
# - güzel. saat büyük ve güzel duruyor Büyük bir salona sahipseniz ideal bir saat ama mekanizma fiyata göre çok dandik daha kaliteli bir şey beklerdim gösterişi falan güzel salonumda çok güzel durdu dışı falan da güzel tek eksisi mekanizma gibi geldi bana Bu fiyata alınırmı bana göre hayır ama özel bi indirim olursa alınır ben yarı fiyatına oldu diye aldım hediye çeki falan kullandım
#
# ==================================================
# LABEL: 2
# ==================================================
# - s7 harika. 1 yıldır kullanıyorum kardesimede yeni aldik mukemmel bir cihaz kesinlikle tavsiye ederim donma kasma vs gibi problemler yok sarj 1 gün rahat gidiyor amiral gemi olduğu hissini kesinlikle veriyor
# - super. Ürün görseldeki gibi geldi kalite olarakta bu paraya alınabilcecek kalitede
# - 5 Yıldız. Hızlı kargo güzel paketleme teşekkürler
# - Beş Yıldız. İyi paketlenmiş olarak elime geçti Cihaz kaliteli ve güzel Tavsiye ederim
# - güzel. Klima taktırcaktık bi arkadasımın evinde gorduk begendık bunu aldık kalitesini belli eden bir ürün kullanıslı tavsiye ederm
# - Beş Yıldız. Gayet memnunum
# - mükemmel. çoçugunu sevindirmek isteyen her ebeveyn icin muthis bir hediye diyebilirim çocuklariniz severek oynayacaktir kesinlikle magaza ayrica bi ilgili ve kargo paketi guzel tesekkuler
# - IYI. HIZLI KARGO URUN DE BENCE FIYATINA GORE IYI SADECE PLASTIGI KOKU VERIYOR
# - Üstün diş temizliği performansı. Genel olarak Oral B braun elektrikli diş fırçasına geçtikten sonra diş temizliği performansında gözle görülür ve hessedilir düzeyde fark hissediyorum Cross Action ve precision serileri de performans anlamında çok memnun olduğum ürünler Hızlı gönderi ve iyi hizmet için teşekkürler HB
# - En eski en köklü firma. Gördüğüm kadarıyla emiş gücü yüksek fakat fazla doldurulunca sızdırılmazlık seviyesi düşüyorBez ne yapsın onunda dayanma gücü var 128514

# %%
etiket_isimleri = {
    0: "Olumsuz",
    1: "Tarafsız",
    2: "Olumlu"
}
# Etiket sayılarını hesapla
etiket_sayilari = (
    df_temiz["label"]
    .value_counts()
    .sort_index()
)

# Sayısal etiketleri duygu isimlerine çevir
etiket_sayilari.index = etiket_sayilari.index.map(etiket_isimleri)

print(etiket_sayilari)

# Grafik
plt.figure(figsize=(8, 5))
etiket_sayilari.plot(kind="bar")

plt.title("Duygu Sınıflarının Dağılımı")
plt.xlabel("Duygu")
plt.ylabel("Yorum Sayısı")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# label
# Olumsuz     77186
# Tarafsız    79219
# Olumlu      90544
# Name: count, dtype: int64

# %%
df_temiz["temiz_metin"] = (
    df_temiz["combined_text"]
    .astype(str)

    # HTML etiketlerini kaldır
    .str.replace(r"<[^>]+>", " ", regex=True)

    # URL'leri kaldır
    .str.replace(r"https?://\S+|www\.\S+", " ", regex=True)

    # Nokta ve virgülleri kaldır
    .str.replace(r"[.,]", " ", regex=True)

    # Birden fazla boşluğu tek boşluğa indir
    .str.replace(r"\s+", " ", regex=True)

    # Baştaki ve sondaki boşlukları kaldır
    .str.strip()
)

# %%
print("Boş metin sayısı:", (df_temiz["temiz_metin"] == "").sum())
print(
    "Temizlik sonrası duplicate:",
    df_temiz["temiz_metin"].duplicated().sum()
)
# Out:
# Boş metin sayısı: 0
# Temizlik sonrası duplicate: 20

# %%
df_temiz = df_temiz[
    df_temiz["temiz_metin"] != ""
].copy()

df_temiz = df_temiz.drop_duplicates(
    subset=["temiz_metin"],
    keep="first"
).reset_index(drop=True)

# %%
df_temiz["karakter_sayisi"] = df_temiz["temiz_metin"].str.len()

df_temiz["kelime_sayisi"] = (
    df_temiz["temiz_metin"]
    .str.split()
    .str.len()
)

df_temiz[["karakter_sayisi", "kelime_sayisi"]].describe()
# Out:
#        karakter_sayisi  kelime_sayisi
# count    246929.000000  246929.000000
# mean        169.984822      25.074455
# std         145.358612      21.016370
# min           7.000000       1.000000
# 25%          78.000000      12.000000
# 50%         134.000000      20.000000
# 75%         213.000000      31.000000
# max        2064.000000     328.000000

# %%
df_temiz[df_temiz["kelime_sayisi"] == 1][
    ["temiz_metin", "label"]
].head(30)
# Out:
#        temiz_metin  label
# 229174    KALİTELİ      2

# %%
df_temiz.head(25)
# Out:
#                                         combined_text  label  karakter_sayisi  \
# 0                                     İki Yıldız. iyi      0               14
# 1   Bir Yıldız. kargo sorunsuz geldi ama tam 1 haf...      0              134
# 2   Kokusu dışında iş görür. Çok fazla koku yapıyo...      0              540
# 3   kötü. saat içinden çıkıyor beklediğim gibi kal...      0               90
# 4   Çok kötü.... Almayın çok kötü boşa para verirs...      0              113
# 5   Bir Yıldız. Cok kalitesiz bir urun kara tahta ...      0              183
# 6   tuş basmıyor. bazı tuşlar basmıyor esc özellik...      0               74
# 7   Demlik kısmındaki çay soğuyor. Sürekli ısıtma ...      0              174
# 8   Damak tadı uymadi. Yorumlara bakarak 3 paket s...      0              333
# 9   eksik urun . aldığım urunun ayakları yok eksik...      0              137
# 10  başarısızzzz. öncelikle ürünü 1 beden büyük al...      0              168
# 11  yeteri kadar saglam değil. eğer kahve fincanı ...      0              240
# 12  Somun yok.... Kargo 2 3 güne elinde Malzemesi ...      0              133
# 13  Sakın almayın. camı malzemesi çok kötü ayrıca ...      0               75
# 14                            Kötü. İncirler çok kötü      0               22
# 15  kremininden referans aldım ama onun kadar kali...      0              302
# 16  İki Yıldız. Paketleme çok kötü boş kutunun içi...      0              103
# 17                                  BERBAT!!!. BERBAT      0               16
# 18  Ürünün sapları dışında güzel. Saplarını eger o...      0              161
# 19  Yenilenen prima berbattt. Kızım 10 aylık doğdu...      0              228
# 20  İki Yıldız. göründüğü gibi değil çok kalitesiz...      0               60
# 21  küçük.. ürün göründüğünden çok küçük normal gö...      0              121
# 22  Hatalı Ürün Gönderimi. Ürünler siparişten 2 ha...      0              139
# 23  Bir Yıldız. ürün iki gün içinde elime ulaştı a...      0              131
# 24  idare eder... ürün gösterişli kullanışlı ve no...      0              267
#
#     kelime_sayisi                                        temiz_metin
# 0               3                                     İki Yıldız iyi
# 1              21  Bir Yıldız kargo sorunsuz geldi ama tam 1 haft...
# 2              77  Kokusu dışında iş görür Çok fazla koku yapıyor...
# 3              13  kötü saat içinden çıkıyor beklediğim gibi kali...
# 4              18  Çok kötü Almayın çok kötü boşa para verirsiniz...
# 5              24  Bir Yıldız Cok kalitesiz bir urun kara tahta k...
# 6              11  tuş basmıyor bazı tuşlar basmıyor esc özellikl...
# 7              24  Demlik kısmındaki çay soğuyor Sürekli ısıtma y...
# 8              50  Damak tadı uymadi Yorumlara bakarak 3 paket si...
# 9              20  eksik urun aldığım urunun ayakları yok eksik c...
# 10             23  başarısızzzz öncelikle ürünü 1 beden büyük alm...
# 11             33  yeteri kadar saglam değil eğer kahve fincanı a...
# 12             24  Somun yok Kargo 2 3 güne elinde Malzemesi kali...
# 13             12  Sakın almayın camı malzemesi çok kötü ayrıca k...
# 14              4                             Kötü İncirler çok kötü
# 15             45  kremininden referans aldım ama onun kadar kali...
# 16             16  İki Yıldız Paketleme çok kötü boş kutunun için...
# 17              2                                   BERBAT!!! BERBAT
# 18             23  Ürünün sapları dışında güzel Saplarını eger or...
# 19             31  Yenilenen prima berbattt Kızım 10 aylık doğduğ...
# 20              9  İki Yıldız göründüğü gibi değil çok kalitesiz ...
# 21             17  küçük ürün göründüğünden çok küçük normal gözl...
# 22             19  Hatalı Ürün Gönderimi Ürünler siparişten 2 haf...
# 23             21  Bir Yıldız ürün iki gün içinde elime ulaştı an...
# 24             37  idare eder ürün gösterişli kullanışlı ve norma...

# %%
df_temiz = df_temiz.drop(
    columns=["karakter_sayisi", "kelime_sayisi"]
)

# %%
df_temiz.head()
# Out:
#                                        combined_text  label  \
# 0                                    İki Yıldız. iyi      0
# 1  Bir Yıldız. kargo sorunsuz geldi ama tam 1 haf...      0
# 2  Kokusu dışında iş görür. Çok fazla koku yapıyo...      0
# 3  kötü. saat içinden çıkıyor beklediğim gibi kal...      0
# 4  Çok kötü.... Almayın çok kötü boşa para verirs...      0
#
#                                          temiz_metin
# 0                                     İki Yıldız iyi
# 1  Bir Yıldız kargo sorunsuz geldi ama tam 1 haft...
# 2  Kokusu dışında iş görür Çok fazla koku yapıyor...
# 3  kötü saat içinden çıkıyor beklediğim gibi kali...
# 4  Çok kötü Almayın çok kötü boşa para verirsiniz...

# %%
df_temiz = df_temiz[["temiz_metin", "label"]]

# %%
df_temiz.head()
# Out:
#                                          temiz_metin  label
# 0                                     İki Yıldız iyi      0
# 1  Bir Yıldız kargo sorunsuz geldi ama tam 1 haft...      0
# 2  Kokusu dışında iş görür Çok fazla koku yapıyor...      0
# 3  kötü saat içinden çıkıyor beklediğim gibi kali...      0
# 4  Çok kötü Almayın çok kötü boşa para verirsiniz...      0

# %%
df_temiz["temiz_metin"] = (
    df_temiz["temiz_metin"]
    .str.replace("I", "ı", regex=False)
    .str.replace("İ", "i", regex=False)
    .str.lower()
)

# %%
df_temiz["temiz_metin"] = (
    df_temiz["temiz_metin"]
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# %%
print(
    "Küçük harfe dönüşüm sonrası duplicate:",
    df_temiz["temiz_metin"].duplicated().sum()
)
# Out:
# Küçük harfe dönüşüm sonrası duplicate: 867

# %%
df_temiz = (
    df_temiz
    .drop_duplicates(subset=["temiz_metin"], keep="first")
    .reset_index(drop=True)
)

# %%
df_temiz[["temiz_metin", "label"]].head(10)
# Out:
#                                          temiz_metin  label
# 0                                     iki yıldız iyi      0
# 1  bir yıldız kargo sorunsuz geldi ama tam 1 haft...      0
# 2  kokusu dışında iş görür çok fazla koku yapıyor...      0
# 3  kötü saat içinden çıkıyor beklediğim gibi kali...      0
# 4  çok kötü almayın çok kötü boşa para verirsiniz...      0
# 5  bir yıldız cok kalitesiz bir urun kara tahta k...      0
# 6  tuş basmıyor bazı tuşlar basmıyor esc özellikl...      0
# 7  demlik kısmındaki çay soğuyor sürekli ısıtma y...      0
# 8  damak tadı uymadi yorumlara bakarak 3 paket si...      0
# 9  eksik urun aldığım urunun ayakları yok eksik c...      0

# %%
print(df_temiz.shape)

print("\nNull değerler:")
print(df_temiz.isnull().sum())

print("\nDuplicate sayısı:")
print(df_temiz["temiz_metin"].duplicated().sum())

print("\nEtiket dağılımı:")
print(df_temiz["label"].value_counts().sort_index())
# Out:
# (246062, 2)
#
# Null değerler:
# temiz_metin    0
# label          0
# dtype: int64
#
# Duplicate sayısı:
# 0
#
# Etiket dağılımı:
# label
# 0    77017
# 1    79028
# 2    90017
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df_temiz["temiz_metin"]
y = df_temiz["label"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Train veri sayısı:", len(X_train))
print("Test veri sayısı:", len(X_test))

print("\nTrain dağılımı:")
print(y_train.value_counts().sort_index())

print("\nTest dağılımı:")
print(y_test.value_counts().sort_index())
# Out:
# Train veri sayısı: 196849
# Test veri sayısı: 49213
#
# Train dağılımı:
# label
# 0    61614
# 1    63222
# 2    72013
# Name: count, dtype: int64
#
# Test dağılımı:
# label
# 0    15403
# 1    15806
# 2    18004
# Name: count, dtype: int64

# %%
train_df.to_csv(
    "../data/processed/hbtrain.csv",
    index=False,
    encoding="utf-8-sig"
)

test_df.to_csv(
    "../data/processed/hbtest.csv",
    index=False,
    encoding="utf-8-sig"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 train_df.to_csv(
#       2     "../data/processed/hbtrain.csv",
#       3     index=False,
#       4     encoding="utf-8-sig"
#       5 )
#       7 test_df.to_csv(
#       8     "../data/processed/hbtest.csv",
#       9     index=False,
#      10     encoding="utf-8-sig"
#      11 )
#
# NameError: name 'train_df' is not defined
